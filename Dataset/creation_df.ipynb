# %%
# %pip install ccxt pandas pandas_ta
# Out:
# Requirement already satisfied: ccxt in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (4.4.85)
# Requirement already satisfied: pandas in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (2.2.3)
# Requirement already satisfied: pandas_ta in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (0.3.14b0)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from ccxt) (65.5.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from ccxt) (2025.4.26)
# Requirement already satisfied: requests>=2.18.4 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from ccxt) (2.32.3)
# Requirement already satisfied: cryptography>=2.6.1 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from ccxt) (45.0.2)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from ccxt) (4.13.2)
# Requirement already satisfied: aiohttp>=3.10.11 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from ccxt) (3.11.18)
# Requirement already satisfied: aiodns>=1.1.1 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from ccxt) (3.4.0)
# Requirement already satisfied: yarl>=1.7.2 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from ccxt) (1.20.0)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pycares>=4.0.0 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from aiodns>=1.1.1->ccxt) (4.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.10.11->ccxt) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.10.11->ccxt) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.10.11->ccxt) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.10.11->ccxt) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.10.11->ccxt) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.10.11->ccxt) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from aiohttp>=3.10.11->ccxt) (0.3.1)
# Requirement already satisfied: idna>=2.0 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from yarl>=1.7.2->ccxt) (3.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from cryptography>=2.6.1->ccxt) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.14->cryptography>=2.6.1->ccxt) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->ccxt) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marius.pingaud\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.18.4->ccxt) (2.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Importers

# %%
import ccxt
import pandas as pd
import pandas_ta as pta
import time
from datetime import datetime, timedelta

# %% [markdown]
# ### Retrieve Online Data

# %%
def fetch_ohlcv_between_dates(
    symbol: str,
    timeframe: str,
    start_date: str,
    end_date: str,
    exchange=None
):
    if exchange is None:
        exchange = ccxt.binance({
            'enableRateLimit': True
        })

    since = exchange.parse8601(start_date)
    end_ts = exchange.parse8601(end_date)
    all_ohlcv = []

    print("📥 Téléchargement des bougies en cours...")

    while since < end_ts:
        ohlcv = exchange.fetch_ohlcv(symbol, timeframe, since=since, limit=1000)
        if not ohlcv:
            break
        all_ohlcv.extend(ohlcv)

        last_timestamp = ohlcv[-1][0]
        if last_timestamp == since:
            break
        since = last_timestamp + 1  # éviter de boucler sur la même bougie

        time.sleep(exchange.rateLimit / 1000)  # respecter le rate limit

    df = pd.DataFrame(
        all_ohlcv,
        columns=['timestamp', 'open', 'high', 'low', 'close', 'volume']
    )
    df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
    df.set_index('timestamp', inplace=True)

    start = pd.to_datetime(start_date).tz_localize(None)
    end = pd.to_datetime(end_date).tz_localize(None)
    df = df[(df.index >= start) & (df.index <= end)]


    print(f"✅ {len(df)} bougies récupérées entre {start_date} et {end_date}")
    return df

# %% [markdown]
# ### Create DataFrame

# %%
df = fetch_ohlcv_between_dates(
    symbol='ETH/EUR',
    timeframe='4h',
    start_date='2025-01-01T00:00:00Z',
    end_date='2025-05-05T00:00:00Z'
)

df.tail()
# Out:
# 📥 Téléchargement des bougies en cours...
# ✅ 745 bougies récupérées entre 2025-01-01T00:00:00Z et 2025-05-05T00:00:00Z
#                         open     high      low    close     volume
# timestamp
# 2025-05-04 08:00:00  1631.76  1631.91  1615.00  1619.93   599.9547
# 2025-05-04 12:00:00  1619.64  1625.74  1612.43  1623.22   509.4224
# 2025-05-04 16:00:00  1622.65  1625.09  1615.40  1620.79   412.3683
# 2025-05-04 20:00:00  1620.90  1632.77  1595.22  1599.42  1214.4687
# 2025-05-05 00:00:00  1599.06  1607.91  1573.07  1585.12  1402.5132

# %% [markdown]
# ### Add some indics to improve training

# %%
import ta

# RSI
df['rsi'] = ta.momentum.RSIIndicator(df['close']).rsi()

# MACD
macd = ta.trend.MACD(df['close'])
df['macd'] = macd.macd()
df['macd_signal'] = macd.macd_signal()

# EMA et SMA
df['ema_20'] = ta.trend.EMAIndicator(df['close'], window=20).ema_indicator()
df['sma_50'] = ta.trend.SMAIndicator(df['close'], window=50).sma_indicator()

# Bollinger Bands
boll = ta.volatility.BollingerBands(df['close'], window=20)
df['bollinger_m'] = boll.bollinger_mavg()
df['bollinger_h'] = boll.bollinger_hband()
df['bollinger_l'] = boll.bollinger_lband()

# ADX
df['adx'] = ta.trend.ADXIndicator(df['high'], df['low'], df['close']).adx()

# OBV
df['obv'] = ta.volume.OnBalanceVolumeIndicator(df['close'], df['volume']).on_balance_volume()

df.tail()
# Out:
#                         open     high      low    close     volume        rsi  \
# timestamp
# 2025-05-04 08:00:00  1631.76  1631.91  1615.00  1619.93   599.9547  52.212564
# 2025-05-04 12:00:00  1619.64  1625.74  1612.43  1623.22   509.4224  53.461405
# 2025-05-04 16:00:00  1622.65  1625.09  1615.40  1620.79   412.3683  52.372741
# 2025-05-04 20:00:00  1620.90  1632.77  1595.22  1599.42  1214.4687  43.905283
# 2025-05-05 00:00:00  1599.06  1607.91  1573.07  1585.12  1402.5132  39.323673
#
#                          macd  macd_signal       ema_20     sma_50  \
# timestamp
# 2025-05-04 08:00:00  8.097296     9.775744  1619.120096  1601.5984
# 2025-05-04 12:00:00  7.490697     9.318735  1619.510563  1602.3376
# 2025-05-04 16:00:00  6.736232     8.802234  1619.632414  1603.2762
# 2025-05-04 20:00:00  4.363631     7.914514  1617.707422  1603.5492
# 2025-05-05 00:00:00  1.314287     6.594468  1614.603858  1603.3046
#
#                      bollinger_m  bollinger_h  bollinger_l        adx  \
# timestamp
# 2025-05-04 08:00:00    1624.4330  1643.622518  1605.243482  11.944796
# 2025-05-04 12:00:00    1625.5435  1641.476850  1609.610150  11.115343
# 2025-05-04 16:00:00    1625.1090  1641.063198  1609.154802  10.345137
# 2025-05-04 20:00:00    1622.9540  1640.484451  1605.423549  10.866209
# 2025-05-05 00:00:00    1620.6030  1644.153237  1597.052763  12.351968
#
#                             obv
# timestamp
# 2025-05-04 08:00:00 -15075.6027
# 2025-05-04 12:00:00 -14566.1803
# 2025-05-04 16:00:00 -14978.5486
# 2025-05-04 20:00:00 -16193.0173
# 2025-05-05 00:00:00 -17595.5305

# %% [markdown]
# ### Verification and filtering

# %%
df.info()
df.isna().sum()

df.dropna(inplace=True)
df.isna().sum()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 696 entries, 2025-01-09 04:00:00 to 2025-05-05 00:00:00
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   open         696 non-null    float64
#  1   high         696 non-null    float64
#  2   low          696 non-null    float64
#  3   close        696 non-null    float64
#  4   volume       696 non-null    float64
#  5   rsi          696 non-null    float64
#  6   macd         696 non-null    float64
#  7   macd_signal  696 non-null    float64
#  8   ema_20       696 non-null    float64
#  9   sma_50       696 non-null    float64
#  10  bollinger_m  696 non-null    float64
#  11  bollinger_h  696 non-null    float64
#  12  bollinger_l  696 non-null    float64
#  13  adx          696 non-null    float64
#  14  obv          696 non-null    float64
# dtypes: float64(15)
# memory usage: 87.0 KB
#                         open     high      low    close    volume        rsi  \
# timestamp
# 2025-01-09 04:00:00  3223.81  3242.34  3188.17  3199.21  208.9777  27.571689
# 2025-01-09 08:00:00  3196.94  3230.31  3174.58  3205.29  431.7211  28.870805
# 2025-01-09 12:00:00  3205.82  3241.44  3115.71  3225.00  686.5435  33.062381
# 2025-01-09 16:00:00  3225.65  3233.64  3101.83  3105.77  603.9169  23.890807
# 2025-01-09 20:00:00  3104.62  3151.03  3068.78  3132.68  688.5189  28.698339
#
#                           macd  macd_signal       ema_20     sma_50  \
# timestamp
# 2025-01-09 04:00:00 -67.489326   -44.385096  3327.124090  3391.8488
# 2025-01-09 08:00:00 -68.359493   -49.179975  3315.520844  3391.2780
# 2025-01-09 12:00:00 -66.689915   -52.681963  3306.899811  3391.2370
# 2025-01-09 16:00:00 -74.133066   -56.972184  3287.744591  3388.8268
# 2025-01-09 20:00:00 -76.973108   -60.972369  3272.976535  3386.8030
#
#                      bollinger_m  bollinger_h  bollinger_l        adx  \
# timestamp
# 2025-01-09 04:00:00    3377.8605  3673.135531  3082.585469  49.660240
# 2025-01-09 08:00:00    3360.7320  3654.313252  3067.150748  49.920375
# 2025-01-09 12:00:00    3345.2765  3633.212449  3057.340551  50.629763
# 2025-01-09 16:00:00    3325.1490  3620.856088  3029.441912  51.387097
# 2025-01-09 20:00:00    3303.0005  3586.442153  3019.558847  52.314730
#
#                            obv
# timestamp
# 2025-01-09 04:00:00 -1824.9093
# 2025-01-09 08:00:00 -1393.1882
# 2025-01-09 12:00:00  -706.6447
# 2025-01-09 16:00:00 -1310.5616
# 2025-01-09 20:00:00  -622.0427

# %% [markdown]
# ### Save it in a CSV

# %%
df.to_csv('df.csv', index=False)
